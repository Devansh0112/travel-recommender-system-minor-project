# %%
import pandas as pd
import numpy as np
df = pd.read_csv('cities.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female        ...         \
# 0                 8587                   7283        ...
# ...

# %%
df1 = df[['name_of_city','population_total','effective_literacy_rate_total','total_graduates']].copy()
df1.head(10)
# Out:
#   name_of_city  population_total  effective_literacy_rate_total  \
# 0      Abohar             145238                          79.86
# 1    Achalpur             112293                          91.99
# 2    Adilabad             117388                          80.51
# 3   Adityapur             173988                          83.46
# 4       Adoni             166537                          68.38
# 5    Agartala             399688                          93.88
# 6        Agra            1574542                          63.44
# 7   Ahmadabad            5570585                          89.62
# 8  Ahmadnagar             350905                          91.49
# 9      Aizawl             291822                          98.80
#
#    total_graduates
# 0            16287
# 1             8863
# 2            10565
# 3            19225
# 4            11902
# 5            52711
# 6           185813
# 7           769858
# 8            51661
# 9            26832

# %%
df1['sample_mean'] = df1.mean(axis=1)
df1.head()
# Out:
#   name_of_city  population_total  effective_literacy_rate_total  \
# 0      Abohar             145238                          79.86
# 1    Achalpur             112293                          91.99
# 2    Adilabad             117388                          80.51
# 3   Adityapur             173988                          83.46
# 4       Adoni             166537                          68.38
#
#    total_graduates   sample_mean
# 0            16287  53868.286667
# 1             8863  40415.996667
# 2            10565  42677.836667
# 3            19225  64432.153333
# 4            11902  59502.460000

# %%
df1['sample_mean'] = df1['sample_mean']/df1['sample_mean'].max()
df1.head()
# Out:
#   name_of_city  population_total  effective_literacy_rate_total  \
# 0      Abohar             145238                          79.86
# 1    Achalpur             112293                          91.99
# 2    Adilabad             117388                          80.51
# 3   Adityapur             173988                          83.46
# 4       Adoni             166537                          68.38
#
#    total_graduates  sample_mean
# 0            16287     0.011316
# 1             8863     0.008490
# 2            10565     0.008965
# 3            19225     0.013535
# 4            11902     0.012500

# %%
a = ['Abohar ','Delhi ','Dehri ']
b = list()
for i in a:
    b.append(df1.loc[df1['name_of_city'] == i , 'sample_mean'].iloc[0])
    
print(b)
# Out:
# [0.011316147182761683, 0.9263458136291595, 0.010638775701176901]

# %%
b = np.mean(b)
b
# Out:
# 0.316100245504366

# %%
filter1 = df1['sample_mean'] > b-0.1
filter2 = df1['sample_mean'] < b+0.1

d = df1['name_of_city'].where(filter1 & filter2)
d = d.dropna()
d
e = list(d)
e
# Out:
# ['Chennai ', 'Jaipur ', 'Kanpur ', 'Kolkata ', 'Lucknow ', 'Pune ', 'Surat ']

# %%
df1.to_csv('hello.csv',index=False)
